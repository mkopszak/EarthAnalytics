# %%
import os
import urllib.request
import pandas as pd
import matplotlib.pyplot as plt
boulder_recip = pd.read_csv("/home/marta/PycharmProjects/Earth analytics/1/downloads/boulder-precip.csv")
boulder_recip.head()
# Out:
#    Unnamed: 0        DATE  PRECIP
# 0         756  2013-08-21     0.1
# 1         757  2013-08-26     0.1
# 2         758  2013-08-27     0.1
# 3         759  2013-09-01     0.0
# 4         760  2013-09-09     0.1

# %%
#fig, ax = plt.boulder_recip
boulder_recip.plot(x="DATE", y="PRECIP")
plt.show()

# %%
plt.rcParams["figure.figsize"] = (12,6)

# create the plot space upon which to plot the data
fig, ax = plt.subplots()
ax.set_xticklabels(boulder_recip["DATE"], rotation=90)
ax.plot(boulder_recip["DATE"], boulder_recip["PRECIP"])
